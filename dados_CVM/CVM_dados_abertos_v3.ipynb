# %%
import os
import numpy as np
import pandas as pd
from zipfile import ZipFile
import wget
import requests
from bs4 import BeautifulSoup as soup

import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 300
plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('seaborn-white')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
lista_empresas = pd.read_csv('match_perfeito.csv', sep=';', encoding='latin1')
lista_empresas = lista_empresas.iloc[:, [1, 3, 4]]
lista_empresas.columns = ['Ticker', 'Empresa', 'CNPJ']
lista_empresas.set_index('Ticker', inplace=True)

# %%
url_lista_empresas = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/CAD/DADOS/cad_cia_aberta.csv'
wget.download(url_lista_empresas)

# %%
urls = [('BPA', 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/BPA/DADOS/'),
        ('BPP', 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/BPP/DADOS'),
        ('DRE', 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DRE/DADOS/'),
        ('DFC_MD', 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DFC_MD/DADOS/'),
        ('DFC_MI', 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DFC_MI/DADOS/'),
        ('ITR', 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/')]

# %%
for url in urls:
    if not 'ITR' in os.listdir():
        os.makedirs(url[0])
    
    print(url[1])
    r = requests.get(url[1])
    p = soup(r.content, 'html.parser')
    tabela = p.find('table', {'id': 'indexlist'})
    linhas = tabela.find_all('tr')[3:]
    
    lista = []
    for linha in linhas:
        try:
            arq = linha.find_all('td')[1].a['href']
            lista.append(arq)
        except:
            pass
        
    for i in lista:
        if not i in os.listdir(url[0]):
            wget.download(url[1] + i, url[1])
# Out:
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/BPA/DADOS/
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/BPP/DADOS
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DRE/DADOS/
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DFC_MD/DADOS/
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DFC_MI/DADOS/
# http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/

# %%
RESULTADO = {}

# %%
def get_ITR_data(cnpj, fillings=['BPA', 'BPP']):
    global RESULTADO
    lista_arquivos = {}
    
    def open_zip_file(arq_zip, nome_csv):
        with ZipFile(arq_zip, 'r') as arquivo:
            if nome_csv in arquivo.namelist(): 
                pass
            
            elif nome_csv not in arquivo.namelist():
                nome_csv = nome_csv.lower()
        
            with arquivo.open(nome_csv) as f:
                tabela = pd.read_csv(f, sep=';', encoding='latin1')
        
        return tabela
    
    def find_data(tabela):
        cnpjs = tabela['CNPJ_CIA'].unique()
        datas = tabela['DT_FIM_EXERC'].unique()
        
        if not cnpj in RESULTADO:
            RESULTADO[cnpj] = {}
        
        if not filling in RESULTADO[cnpj]:
            RESULTADO[cnpj][filling] = {}

        for data in datas:
            t = tabela[(tabela['CNPJ_CIA']==cnpj) & (tabela['DT_FIM_EXERC']==data)].copy()
            
            if not data in RESULTADO[cnpj][filling]:
                RESULTADO[cnpj][filling][data] = {}
            
            for i in range(t.shape[0]):
                RESULTADO[cnpj][filling][data][t.iloc[i]['DS_CONTA']] = t.iloc[i]['VL_CONTA']
    
    for filling in fillings:
        lista_arquivos[filling] = [i for i in os.listdir(filling) if i[-4:] == '.zip']
        lista_arquivos['ITR'] = [i for i in os.listdir('ITR') if i[-4:] == '.zip']
        
        for arq_zip in lista_arquivos[filling]:
            nome_csv = '%s_CIA_ABERTA_con_%s.csv' % (filling, arq_zip[-8:-4])    
            tabela = open_zip_file(filling + '/' + arq_zip, nome_csv)
            find_data(tabela)
        
        for arq_zip in lista_arquivos['ITR']:
            nome_csv = 'ITR_CIA_ABERTA_%s_con_%s.csv' % (filling, arq_zip[-8:-4])
            tabela = open_zip_file('ITR/' + arq_zip, nome_csv)
            find_data(tabela)

# %%
def desacumular(df):
    x = df.copy()
    x_ = df.copy()
    for c in x.columns:
        for i in range(x.shape[0]):
            month = x.iloc[i].name.month
            year = x.iloc[i].name.year

            if month > 3:
                try:
                    x_.loc['%d-%d' % (year, month), c] = x.loc['%d-%d' % (year, month), c].values - x.loc['%d-%d' % (year, month-3), c].values
                except:
                    pass
                
    return x_

# %%
class Empresa:
    
    def __init__(self, ticker, cnpj=''):
        self.ticker = ticker
        self.name = lista_empresas.loc[ticker]['Empresa']
        
        if cnpj == '': self.cnpj = lista_empresas.loc[ticker]['CNPJ']
        else: self.cnpj = cnpj
        
    def get_balance_sheet(self):
        get_ITR_data(self.cnpj)
        BPA = pd.DataFrame(RESULTADO[self.cnpj]['BPA']).dropna(axis=1, how='all')
        BPP = pd.DataFrame(RESULTADO[self.cnpj]['BPP']).dropna(axis=1, how='all')
        
        self.BP = pd.concat([BPA, BPP], axis=0).T.sort_index().T
        return self.BP
    
    def get_income_statement(self):
        get_ITR_data(self.cnpj, fillings=['DRE'])
        t_ = pd.DataFrame(RESULTADO[self.cnpj]['DRE']).dropna(axis=1, how='all').T.sort_index().reset_index()
        t_['index'] = pd.to_datetime(t_['index'])
        t_ = t_.set_index('index')
            
        self.DRE = desacumular(t_).T.copy()
        return self.DRE
        
    def get_dfc_md(self):
        get_ITR_data(self.cnpj, fillings=['DFC_MD'])
        t_ = pd.DataFrame(RESULTADO[self.cnpj]['DFC_MD']).dropna(axis=1, how='all').T.sort_index().reset_index()
        t_['index'] = pd.to_datetime(t_['index'])
        t_ = t_.set_index('index')
            
        self.DFC_D = desacumular(t_).T.copy()
        return self.DFC_D
        
    def get_dfc_mi(self):
        get_ITR_data(self.cnpj, fillings=['DFC_MI'])
        t_ = pd.DataFrame(RESULTADO[self.cnpj]['DFC_MI']).dropna(axis=1, how='all').T.sort_index().reset_index()
        t_['index'] = pd.to_datetime(t_['index'])
        t_ = t_.set_index('index')
            
        self.DFC_I = desacumular(t_).T.copy()
        return self.DFC_I

# %%
t = Empresa('ABEV3')

# %%
t.get_income_statement()
# Out:
# index                                               2012-06-30  2012-09-30  \
# Receita de Venda de Bens e/ou Serviços              14061117.0   8036022.0
# Custo dos Bens e/ou Serviços Vendidos               -4703366.0  -2667728.0
# Resultado Bruto                                      9357751.0   5368294.0
# Despesas/Receitas Operacionais                      -3946153.0  -2099358.0
# Despesas com Vendas                                 -3552955.0  -1821806.0
# Despesas Gerais e Administrativas                    -674200.0   -519477.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          347495.0    211751.0
# Outras Despesas Operacionais                          -66552.0     30142.0
# Resultado de Equivalência Patrimonial                     59.0        32.0
# Resultado Antes do Resultado Financeiro e dos T...   5411598.0   3268936.0
# Resultado Financeiro                                 -265184.0   -365523.0
# Receitas Financeiras                                  334972.0    185188.0
# Despesas Financeiras                                 -600156.0   -550711.0
# Resultado Antes dos Tributos sobre o Lucro           5146414.0   2903413.0
# Imposto de Renda e Contribuição Social sobre o ...   -942736.0   -420058.0
# Corrente                                            -1316954.0   -362216.0
# Diferido                                              374218.0    -57842.0
# Resultado Líquido das Operações Continuadas          4203678.0   2483355.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                4203678.0   2483355.0
# Atribuído a Sócios da Empresa Controladora           2550363.0   1514399.0
# Atribuído a Sócios Não Controladores                 1653315.0    968956.0
#
# index                                               2012-12-31  2013-03-31  \
# Receita de Venda de Bens e/ou Serviços              10133888.0   7832000.0
# Custo dos Bens e/ou Serviços Vendidos               -3088692.0  -2697779.0
# Resultado Bruto                                      7045196.0   5134221.0
# Despesas/Receitas Operacionais                      -2095410.0  -2021782.0
# Despesas com Vendas                                 -1976159.0  -1993527.0
# Despesas Gerais e Administrativas                    -409872.0   -353084.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          410531.0    328786.0
# Outras Despesas Operacionais                         -120300.0     -5645.0
# Resultado de Equivalência Patrimonial                    390.0      1688.0
# Resultado Antes do Resultado Financeiro e dos T...   4949786.0   3112439.0
# Resultado Financeiro                                 -258970.0   -237758.0
# Receitas Financeiras                                  146603.0    162769.0
# Despesas Financeiras                                 -405573.0   -400527.0
# Resultado Antes dos Tributos sobre o Lucro           4690816.0   2874681.0
# Imposto de Renda e Contribuição Social sobre o ...   -957271.0   -501446.0
# Corrente                                             -396050.0   -763448.0
# Diferido                                             -561221.0    262002.0
# Resultado Líquido das Operações Continuadas          3733545.0   2373235.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                3733545.0   2373235.0
# Atribuído a Sócios da Empresa Controladora           2262529.0   1442299.0
# Atribuído a Sócios Não Controladores                 1471016.0    930936.0
#
# index                                               2013-06-30  2013-09-30  \
# Receita de Venda de Bens e/ou Serviços               7570220.0   8544259.0
# Custo dos Bens e/ou Serviços Vendidos               -2667024.0  -2884137.0
# Resultado Bruto                                      4903196.0   5660122.0
# Despesas/Receitas Operacionais                      -2201410.0  -1973603.0
# Despesas com Vendas                                 -2092677.0  -2009291.0
# Despesas Gerais e Administrativas                    -403748.0   -355599.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          303548.0    508249.0
# Outras Despesas Operacionais                           -8630.0   -120854.0
# Resultado de Equivalência Patrimonial                     97.0      3892.0
# Resultado Antes do Resultado Financeiro e dos T...   2701786.0   3686519.0
# Resultado Financeiro                                 -267338.0   -497394.0
# Receitas Financeiras                                  126271.0    185586.0
# Despesas Financeiras                                 -393609.0   -682980.0
# Resultado Antes dos Tributos sobre o Lucro           2434448.0   3189125.0
# Imposto de Renda e Contribuição Social sobre o ...   -523109.0   -839172.0
# Corrente                                             -637176.0   -376871.0
# Diferido                                              114067.0   -462301.0
# Resultado Líquido das Operações Continuadas          1911339.0   2349953.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                1911339.0   2349953.0
# Atribuído a Sócios da Empresa Controladora           1147409.0   2293889.0
# Atribuído a Sócios Não Controladores                  763930.0     56064.0
#
# index                                               2013-12-31  2014-03-31  \
# Receita de Venda de Bens e/ou Serviços              11132628.0   9045072.0
# Custo dos Bens e/ou Serviços Vendidos               -3323603.0  -3008314.0
# Resultado Bruto                                      7809025.0   6036758.0
# Despesas/Receitas Operacionais                      -1867578.0  -2519280.0
# Despesas com Vendas                                 -1964421.0  -2315433.0
# Despesas Gerais e Administrativas                    -635909.0   -443428.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          852810.0    292404.0
# Outras Despesas Operacionais                         -125800.0    -60693.0
# Resultado de Equivalência Patrimonial                   5742.0      7870.0
# Resultado Antes do Resultado Financeiro e dos T...   5941447.0   3517478.0
# Resultado Financeiro                                 -558893.0   -368821.0
# Receitas Financeiras                                  458955.0    207567.0
# Despesas Financeiras                                -1017848.0   -576388.0
# Resultado Antes dos Tributos sobre o Lucro           5382554.0   3148657.0
# Imposto de Renda e Contribuição Social sobre o ...   -617644.0   -551856.0
# Corrente                                             -158474.0   -955095.0
# Diferido                                             -459170.0    403239.0
# Resultado Líquido das Operações Continuadas          4764910.0   2596801.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                4764910.0   2596801.0
# Atribuído a Sócios da Empresa Controladora           4673727.0   2546639.0
# Atribuído a Sócios Não Controladores                   91183.0     50162.0
#
# index                                               2014-06-30  2014-09-30  \
# Receita de Venda de Bens e/ou Serviços               8177433.0   8624396.0
# Custo dos Bens e/ou Serviços Vendidos               -3040666.0  -2955760.0
# Resultado Bruto                                      5136767.0   5668636.0
# Despesas/Receitas Operacionais                      -2367188.0  -2175213.0
# Despesas com Vendas                                 -2347222.0  -2159875.0
# Despesas Gerais e Administrativas                    -354940.0   -394205.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          422247.0    404289.0
# Outras Despesas Operacionais                          -89573.0    -28465.0
# Resultado de Equivalência Patrimonial                   2300.0      3043.0
# Resultado Antes do Resultado Financeiro e dos T...   2769579.0   3493423.0
# Resultado Financeiro                                 -298002.0   -221091.0
# Receitas Financeiras                                  275869.0    345085.0
# Despesas Financeiras                                 -573871.0   -566176.0
# Resultado Antes dos Tributos sobre o Lucro           2471577.0   3272332.0
# Imposto de Renda e Contribuição Social sobre o ...   -255971.0   -381788.0
# Corrente                                             -286881.0   -857676.0
# Diferido                                               30910.0    475888.0
# Resultado Líquido das Operações Continuadas          2215606.0   2890544.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                2215606.0   2890544.0
# Atribuído a Sócios da Empresa Controladora           2166882.0   2813598.0
# Atribuído a Sócios Não Controladores                   48724.0     76946.0
#
# index                                               ...  2017-09-30  \
# Receita de Venda de Bens e/ou Serviços              ...  11362303.0
# Custo dos Bens e/ou Serviços Vendidos               ...  -4482122.0
# Resultado Bruto                                     ...   6880181.0
# Despesas/Receitas Operacionais                      ...  -3270946.0
# Despesas com Vendas                                 ...  -2971041.0
# Despesas Gerais e Administrativas                   ...   -528467.0
# Perdas pela Não Recuperabilidade de Ativos          ...         0.0
# Outras Receitas Operacionais                        ...    289770.0
# Outras Despesas Operacionais                        ...    -56673.0
# Resultado de Equivalência Patrimonial               ...     -4535.0
# Resultado Antes do Resultado Financeiro e dos T...  ...   3609235.0
# Resultado Financeiro                                ...   -674932.0
# Receitas Financeiras                                ...    186131.0
# Despesas Financeiras                                ...   -861063.0
# Resultado Antes dos Tributos sobre o Lucro          ...   2934303.0
# Imposto de Renda e Contribuição Social sobre o ...  ...  -2797813.0
# Corrente                                            ...  -3715267.0
# Diferido                                            ...    917454.0
# Resultado Líquido das Operações Continuadas         ...    136490.0
# Resultado Líquido de Operações Descontinuadas       ...         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...  ...         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...  ...         0.0
# Lucro/Prejuízo Consolidado do Período               ...    136490.0
# Atribuído a Sócios da Empresa Controladora          ...       223.0
# Atribuído a Sócios Não Controladores                ...    136267.0
#
# index                                               2017-12-31  2018-03-31  \
# Receita de Venda de Bens e/ou Serviços              15027215.0  11640219.0
# Custo dos Bens e/ou Serviços Vendidos               -4988326.0  -4455934.0
# Resultado Bruto                                     10038889.0   7184285.0
# Despesas/Receitas Operacionais                      -3769479.0  -3382951.0
# Despesas com Vendas                                 -3168599.0  -3061504.0
# Despesas Gerais e Administrativas                   -1018890.0   -571192.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          476209.0    307434.0
# Outras Despesas Operacionais                          -53318.0    -58306.0
# Resultado de Equivalência Patrimonial                  -4881.0       617.0
# Resultado Antes do Resultado Financeiro e dos T...   6269410.0   3801334.0
# Resultado Financeiro                                -1247547.0   -599222.0
# Receitas Financeiras                                  341734.0    375541.0
# Despesas Financeiras                                -1589281.0   -974763.0
# Resultado Antes dos Tributos sobre o Lucro           5021863.0   3202112.0
# Imposto de Renda e Contribuição Social sobre o ...  -1722513.0   -614526.0
# Corrente                                             -358014.0   -728053.0
# Diferido                                            -1364499.0    113527.0
# Resultado Líquido das Operações Continuadas          3299350.0   2587586.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                3299350.0   2587586.0
# Atribuído a Sócios da Empresa Controladora           3119462.0   2505919.0
# Atribuído a Sócios Não Controladores                  179888.0     81667.0
#
# index                                               2018-06-30  2018-09-30  \
# Receita de Venda de Bens e/ou Serviços              11509545.0  11063743.0
# Custo dos Bens e/ou Serviços Vendidos               -4382306.0  -4365818.0
# Resultado Bruto                                      7127239.0   6697925.0
# Despesas/Receitas Operacionais                      -3441561.0  -3292941.0
# Despesas com Vendas                                 -3142127.0  -2859329.0
# Despesas Gerais e Administrativas                    -581644.0   -615809.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          463338.0    266181.0
# Outras Despesas Operacionais                         -183683.0    -80712.0
# Resultado de Equivalência Patrimonial                   2555.0     -3272.0
# Resultado Antes do Resultado Financeiro e dos T...   3685678.0   3404984.0
# Resultado Financeiro                                -1101952.0   -660735.0
# Receitas Financeiras                                   98044.0    245289.0
# Despesas Financeiras                                -1199996.0   -906024.0
# Resultado Antes dos Tributos sobre o Lucro           2583726.0   2744249.0
# Imposto de Renda e Contribuição Social sobre o ...   -172679.0    141109.0
# Corrente                                             -663297.0   -475185.0
# Diferido                                              490618.0    616294.0
# Resultado Líquido das Operações Continuadas          2411047.0   2885358.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                2411047.0   2885358.0
# Atribuído a Sócios da Empresa Controladora           2304038.0   2824411.0
# Atribuído a Sócios Não Controladores                  107009.0     60947.0
#
# index                                               2018-12-31  2019-03-31  \
# Receita de Venda de Bens e/ou Serviços              16017829.0  12640126.0
# Custo dos Bens e/ou Serviços Vendidos               -6045365.0  -5107701.0
# Resultado Bruto                                      9972464.0   7532425.0
# Despesas/Receitas Operacionais                      -3712557.0  -3478828.0
# Despesas com Vendas                                 -3265551.0  -3028003.0
# Despesas Gerais e Administrativas                    -594820.0   -661522.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          390716.0    285051.0
# Outras Despesas Operacionais                         -244042.0    -72218.0
# Resultado de Equivalência Patrimonial                   1140.0     -2136.0
# Resultado Antes do Resultado Financeiro e dos T...   6259907.0   4053597.0
# Resultado Financeiro                                -1668391.0   -672068.0
# Receitas Financeiras                                  -64981.0    287693.0
# Despesas Financeiras                                -1603410.0   -959761.0
# Resultado Antes dos Tributos sobre o Lucro           4591516.0   3381529.0
# Imposto de Renda e Contribuição Social sobre o ...  -1127797.0   -632461.0
# Corrente                                               33055.0   -979185.0
# Diferido                                            -1160852.0    346724.0
# Resultado Líquido das Operações Continuadas          3463719.0   2749068.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                3463719.0   2749068.0
# Atribuído a Sócios da Empresa Controladora           3360593.0   2661850.0
# Atribuído a Sócios Não Controladores                  103126.0     87218.0
#
# index                                               2019-06-30  2019-09-30  \
# Receita de Venda de Bens e/ou Serviços              12145133.0  11957652.0
# Custo dos Bens e/ou Serviços Vendidos               -4961301.0  -5229732.0
# Resultado Bruto                                      7183832.0   6727920.0
# Despesas/Receitas Operacionais                      -3636384.0  -3595705.0
# Despesas com Vendas                                 -3085118.0  -3078160.0
# Despesas Gerais e Administrativas                    -707400.0   -632466.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0         0.0
# Outras Receitas Operacionais                          273442.0    154355.0
# Outras Despesas Operacionais                         -116577.0    -31186.0
# Resultado de Equivalência Patrimonial                   -731.0     -8248.0
# Resultado Antes do Resultado Financeiro e dos T...   3547448.0   3132215.0
# Resultado Financeiro                                 -567437.0   -305798.0
# Receitas Financeiras                                  249903.0    867205.0
# Despesas Financeiras                                 -817340.0  -1173003.0
# Resultado Antes dos Tributos sobre o Lucro           2980011.0   2826417.0
# Imposto de Renda e Contribuição Social sobre o ...   -364110.0   -222032.0
# Corrente                                             -807524.0   -649270.0
# Diferido                                              443414.0    427238.0
# Resultado Líquido das Operações Continuadas          2615901.0   2604385.0
# Resultado Líquido de Operações Descontinuadas              0.0         0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0         0.0
# Lucro/Prejuízo Consolidado do Período                2615901.0   2604385.0
# Atribuído a Sócios da Empresa Controladora           2520733.0   2497677.0
# Atribuído a Sócios Não Controladores                   95168.0    106708.0
#
# index                                               2019-12-31
# Receita de Venda de Bens e/ou Serviços              15856798.0
# Custo dos Bens e/ou Serviços Vendidos               -6379425.0
# Resultado Bruto                                      9477373.0
# Despesas/Receitas Operacionais                      -4158061.0
# Despesas com Vendas                                 -3456255.0
# Despesas Gerais e Administrativas                    -678579.0
# Perdas pela Não Recuperabilidade de Ativos                 0.0
# Outras Receitas Operacionais                          393916.0
# Outras Despesas Operacionais                         -405948.0
# Resultado de Equivalência Patrimonial                 -11195.0
# Resultado Antes do Resultado Financeiro e dos T...   5319312.0
# Resultado Financeiro                                -1564264.0
# Receitas Financeiras                                  234065.0
# Despesas Financeiras                                -1798329.0
# Resultado Antes dos Tributos sobre o Lucro           3755048.0
# Imposto de Renda e Contribuição Social sobre o ...    463930.0
# Corrente                                             1317925.0
# Diferido                                             -853995.0
# Resultado Líquido das Operações Continuadas          4218978.0
# Resultado Líquido de Operações Descontinuadas              0.0
# Lucro/Prejuízo Líquido das Operações Descontinu...         0.0
# Ganhos/Perdas Líquidas sobre Ativos de Operaçõe...         0.0
# Lucro/Prejuízo Consolidado do Período                4218978.0
# Atribuído a Sócios da Empresa Controladora           4099705.0
# Atribuído a Sócios Não Controladores                  119273.0
#
# [25 rows x 31 columns]
